# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect("./dev/cademycode.db")
curs = conn.cursor()

# %%
curs.execute("""SELECT * FROM sqlite_master WHERE type='table'""")
curs.fetchall()
# Out:
# [('table',
#   'cademycode_students',
#   'cademycode_students',
#   2,
#   'CREATE TABLE cademycode_students (\n\tuuid INTEGER, \n\tname VARCHAR, \n\tdob VARCHAR, \n\tsex TEXT, \n\tcontact_info JSON, \n\tjob_id VARCHAR, \n\tnum_course_taken VARCHAR, \n\tcurrent_career_path_id VARCHAR, \n\ttime_spent_hrs VARCHAR\n)'),
#  ('table',
#   'cademycode_courses',
#   'cademycode_courses',
#   5,
#   'CREATE TABLE cademycode_courses (\n\tcareer_path_id BIGINT, \n\tcareer_path_name TEXT, \n\thours_to_complete BIGINT\n)'),
#  ('table',
#   'cademycode_student_jobs',
#   'cademycode_student_jobs',
#   6,
#   'CREATE TABLE cademycode_student_jobs (\n\tjob_id BIGINT, \n\tjob_category TEXT, \n\tavg_salary BIGINT\n)')]

# %%
df_students = pd.read_sql_query("SELECT uuid, name, dob, sex, contact_info, job_id, num_course_taken, current_career_path_id, time_spent_hrs FROM cademycode_students", conn)
df_courses = pd.read_sql_query("SELECT career_path_id, career_path_name, hours_to_complete FROM cademycode_courses", conn)
df_stud_jobs = pd.read_sql_query("SELECT job_id, job_category, avg_salary FROM cademycode_student_jobs", conn)

# %%
conn.close()

# %%
df_students.head()
# Out:
#    uuid             name         dob sex  \
# 0     1  Annabelle Avery  1943-07-03   F
# 1     2      Micah Rubio  1991-02-07   M
# 2     3       Hosea Dale  1989-12-07   M
# 3     4     Mariann Kirk  1988-07-31   F
# 4     5  Lucio Alexander  1963-08-31   M
#
#                                         contact_info job_id num_course_taken  \
# 0  {"mailing_address": "303 N Timber Key, Irondal...    7.0              6.0
# 1  {"mailing_address": "767 Crescent Fair, Shoals...    7.0              5.0
# 2  {"mailing_address": "P.O. Box 41269, St. Bonav...    7.0              8.0
# 3  {"mailing_address": "517 SE Wintergreen Isle, ...    6.0              7.0
# 4  {"mailing_address": "18 Cinder Cliff, Doyles b...    7.0             14.0
#
#   current_career_path_id time_spent_hrs
# 0                    1.0           4.99
# 1                    8.0            4.4
# 2                    8.0           6.74
# 3                    9.0          12.31
# 4                    3.0           5.64

# %%
df_courses.columns
# Out:
# Index(['career_path_id', 'career_path_name', 'hours_to_complete'], dtype='object')

# %%
df_stud_jobs.columns
# Out:
# Index(['job_id', 'job_category', 'avg_salary'], dtype='object')

# %%
df_students.columns
# Out:
# Index(['uuid', 'name', 'dob', 'sex', 'contact_info', 'job_id',
#        'num_course_taken', 'current_career_path_id', 'time_spent_hrs'],
#       dtype='object')

# %%
df_courses
# Out:
#    career_path_id           career_path_name  hours_to_complete
# 0               1             data scientist                 20
# 1               2              data engineer                 20
# 2               3               data analyst                 12
# 3               4       software engineering                 25
# 4               5           backend engineer                 18
# 5               6          frontend engineer                 20
# 6               7              iOS developer                 27
# 7               8          android developer                 27
# 8               9  machine learning engineer                 35
# 9              10             ux/ui designer                 15

# %%
df_courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   career_path_id     10 non-null     int64
#  1   career_path_name   10 non-null     object
#  2   hours_to_complete  10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 368.0+ bytes

# %%
df_stud_jobs
# Out:
#     job_id        job_category  avg_salary
# 0        1           analytics       86000
# 1        2            engineer      101000
# 2        3  software developer      110000
# 3        4            creative       66000
# 4        5  financial services      135000
# 5        6           education       61000
# 6        7                  HR       80000
# 7        8             student       10000
# 8        9          healthcare      120000
# 9        0               other       80000
# 10       3  software developer      110000
# 11       4            creative       66000
# 12       5  financial services      135000

# %%
df_stud_jobs.drop([10,11,12], inplace=True, errors='ignore')
df_stud_jobs
# Out:
#    job_id        job_category  avg_salary
# 0       1           analytics       86000
# 1       2            engineer      101000
# 2       3  software developer      110000
# 3       4            creative       66000
# 4       5  financial services      135000
# 5       6           education       61000
# 6       7                  HR       80000
# 7       8             student       10000
# 8       9          healthcare      120000
# 9       0               other       80000

# %% [markdown]
# Indexes 10, 11, 12 are duplicates of 2, 3 and 4.

# %%
df_stud_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   job_id        10 non-null     int64
#  1   job_category  10 non-null     object
#  2   avg_salary    10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 368.0+ bytes

# %%
df_stud_jobs['job_id'] = df_stud_jobs['job_id'].astype('float')
df_stud_jobs.dtypes
# Out:
# job_id          float64
# job_category     object
# avg_salary        int64
# dtype: object

# %%
df_courses['career_path_id'] = df_courses['career_path_id'].astype('float')
df_courses.dtypes
# Out:
# career_path_id       float64
# career_path_name      object
# hours_to_complete      int64
# dtype: object

# %%
df_students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uuid                    5000 non-null   int64
#  1   name                    5000 non-null   object
#  2   dob                     5000 non-null   object
#  3   sex                     5000 non-null   object
#  4   contact_info            5000 non-null   object
#  5   job_id                  4995 non-null   object
#  6   num_course_taken        4749 non-null   object
#  7   current_career_path_id  4529 non-null   object
#  8   time_spent_hrs          4529 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 351.7+ KB

# %% [markdown]
# job_id, num_course_taken, current_career_path_id, time_spent_hrs :
#
# - potential change Dtype to numeric
# - job_id, current_career_path_id are integers in other tables. Deal with nulls by creating a new row in other tables and assigning them that ?
# - other two set to float, so null is still available

# %%
df_students.sex.value_counts()
# Out:
# M    1995
# F    1990
# N    1015
# Name: sex, dtype: int64

# %%
df_students.columns.values
# Out:
# array(['uuid', 'name', 'dob', 'sex', 'contact_info', 'job_id',
#        'num_course_taken', 'current_career_path_id', 'time_spent_hrs'],
#       dtype=object)

# %%
df_students['job_id'].value_counts()
# Out:
# 2.0    706
# 1.0    693
# 7.0    680
# 3.0    675
# 4.0    671
# 5.0    660
# 6.0    657
# 8.0    253
# Name: job_id, dtype: int64

# %%
df_students['current_career_path_id'].value_counts()
# Out:
# 5.0     476
# 3.0     469
# 10.0    460
# 1.0     459
# 6.0     454
# 2.0     450
# 7.0     449
# 9.0     441
# 8.0     437
# 4.0     434
# Name: current_career_path_id, dtype: int64

# %%
df_students['time_spent_hrs'].value_counts()
# Out:
# 5.93     8
# 17.47    8
# 11.9     7
# 7.05     7
# 2.91     7
#         ..
# 27.53    1
# 8.07     1
# 27.51    1
# 29.66    1
# 23.54    1
# Name: time_spent_hrs, Length: 2192, dtype: int64

# %%
df_students['num_course_taken'].value_counts()
# Out:
# 5.0     341
# 12.0    332
# 2.0     312
# 15.0    309
# 10.0    306
# 7.0     303
# 13.0    297
# 0.0     296
# 8.0     291
# 11.0    289
# 4.0     285
# 6.0     282
# 14.0    280
# 3.0     279
# 1.0     279
# 9.0     268
# Name: num_course_taken, dtype: int64

# %%
df_students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uuid                    5000 non-null   int64
#  1   name                    5000 non-null   object
#  2   dob                     5000 non-null   object
#  3   sex                     5000 non-null   object
#  4   contact_info            5000 non-null   object
#  5   job_id                  4995 non-null   object
#  6   num_course_taken        4749 non-null   object
#  7   current_career_path_id  4529 non-null   object
#  8   time_spent_hrs          4529 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 351.7+ KB

# %% [markdown]
# Convert date of birth column to datetime data type

# %%
df_students['dob'] = pd.to_datetime(df_students['dob'])
df_students.dtypes
# Out:
# uuid                               int64
# name                              object
# dob                       datetime64[ns]
# sex                               object
# contact_info                      object
# job_id                            object
# num_course_taken                  object
# current_career_path_id            object
# time_spent_hrs                    object
# dtype: object

# %%
df_no_job_id = df_students[df_students['job_id'].isna()]
df_no_job_id
# Out:
#       uuid              name        dob sex  \
# 162    163        Glen Riley 2002-08-22   M
# 757    758  Mercedez Vorberg 2002-03-25   F
# 854    855           Kurt Ho 2002-05-29   M
# 1029  1030      Penny Gaines 2002-03-01   N
# 1542  1543  Frederick Reilly 2002-11-13   M
#
#                                            contact_info job_id  \
# 162   {"mailing_address": "P.O. Box 37267, Cornlea v...   None
# 757   {"mailing_address": "284 Cedar Seventh, Virden...   None
# 854   {"mailing_address": "P.O. Box 27254, Olin, New...   None
# 1029  {"mailing_address": "138 Misty Vale, Stockton ...   None
# 1542  {"mailing_address": "P.O. Box 40769, Quakervil...   None
#
#      num_course_taken current_career_path_id time_spent_hrs
# 162               8.0                    3.0            5.7
# 757              15.0                    4.0           4.14
# 854               0.0                    8.0          23.72
# 1029             15.0                    4.0          16.25
# ...

# %%
df_students[df_students['num_course_taken'].isna()].head(10)
# Out:
#      uuid              name        dob sex  \
# 25     26     Doug Browning 1970-06-08   M
# 26     27   Damon Schrauwen 1953-10-31   M
# 51     52        Alisa Neil 1977-05-28   F
# 70     71   Chauncey Hooper 1962-04-07   M
# 80     81   Ellyn van Heest 1984-06-28   F
# 96     97     Moises Krekel 2004-06-15   M
# 139   140  Charlie Semvoort 2004-03-06   N
# 149   150   Lindsey Mcclain 1972-11-30   N
# 157   158    Ching Rijkensz 1988-02-17   N
# 202   203     Bettie Torres 1973-06-05   N
#
#                                           contact_info job_id  \
# 25   {"mailing_address": "P.O. Box 15845, Devine, F...    7.0
# 26   {"mailing_address": "P.O. Box 84659, Maben, Ge...    4.0
# 51   {"mailing_address": "16 View Annex, Mosses, No...    5.0
# 70   {"mailing_address": "955 Dewy Flat, Slaughterv...    3.0
# 80   {"mailing_address": "872 Cider Glade, Chicken,...    3.0
# 96   {"mailing_address": "455 Silent Smith, Radium ...    8.0
# ...

# %%
df_students[df_students['num_course_taken'] == "0.0"].head(10)
# Out:
#      uuid              name        dob sex  \
# 15     16     Norene Dalton 1976-04-30   F
# 35     36      Natalie Goff 1978-01-17   F
# 60     61   Jule Schermerts 1981-03-14   F
# 94     95       Kylee Brown 1952-07-29   F
# 97     98    Martin Ramirez 1963-12-24   M
# 117   118     Jeane Weenink 1968-06-24   F
# 133   134  Tomas Bosschaert 1984-06-02   M
# 148   149    Emelda Miedema 1962-05-01   F
# 176   177      Louis Ploegh 1956-01-15   N
# 183   184        Lee Mercer 1980-02-19   M
#
#                                           contact_info job_id  \
# 15   {"mailing_address": "130 Wishing Essex, Branch...    6.0
# 35   {"mailing_address": "961 Squaw Crest, Bonner S...    6.0
# 60   {"mailing_address": "602 Heather Bay, Hazelwoo...    6.0
# 94   {"mailing_address": "259 Merry Highlands, Thor...    4.0
# 97   {"mailing_address": "317 S Quay, Eldred villag...    6.0
# 117  {"mailing_address": "598 Park Parkway, Ammon, ...    4.0
# ...

# %%
to_num = ['job_id', 'num_course_taken', 'current_career_path_id', 'time_spent_hrs']
for c in to_num:
  df_students[c] = pd.to_numeric(df_students[c])
df_students.dtypes
# Out:
# uuid                               int64
# name                              object
# dob                       datetime64[ns]
# sex                               object
# contact_info                      object
# job_id                           float64
# num_course_taken                 float64
# current_career_path_id           float64
# time_spent_hrs                   float64
# dtype: object

# %%
df_students.describe()
# Out:
#               uuid       job_id  num_course_taken  current_career_path_id  \
# count  5000.000000  4995.000000       4749.000000             4529.000000
# mean   2500.500000     4.172172          7.533586                5.478914
# std    1443.520003     2.148098          4.609884                2.874135
# min       1.000000     1.000000          0.000000                1.000000
# 25%    1250.750000     2.000000          4.000000                3.000000
# 50%    2500.500000     4.000000          7.000000                5.000000
# 75%    3750.250000     6.000000         12.000000                8.000000
# max    5000.000000     8.000000         15.000000               10.000000
#
#        time_spent_hrs
# count     4529.000000
# mean        11.520625
# std          7.564228
# min          0.000000
# 25%          5.380000
# 50%         10.670000
# 75%         16.750000
# max         35.980000

# %%
df_students = df_students.drop(['name', 'contact_info'], axis=1)

# %%
full_df_a = df_students.merge(df_stud_jobs, left_on='job_id', right_on='job_id', how='left')
full_df_a.head()
# Out:
#    uuid        dob sex  job_id  num_course_taken  current_career_path_id  \
# 0     1 1943-07-03   F     7.0               6.0                     1.0
# 1     2 1991-02-07   M     7.0               5.0                     8.0
# 2     3 1989-12-07   M     7.0               8.0                     8.0
# 3     4 1988-07-31   F     6.0               7.0                     9.0
# 4     5 1963-08-31   M     7.0              14.0                     3.0
#
#    time_spent_hrs job_category  avg_salary
# 0            4.99           HR     80000.0
# 1            4.40           HR     80000.0
# 2            6.74           HR     80000.0
# 3           12.31    education     61000.0
# 4            5.64           HR     80000.0

# %%
df_complete = full_df_a.merge(df_courses, left_on='current_career_path_id', right_on='career_path_id', how='left')
df_complete.head()
# Out:
#    uuid        dob sex  job_id  num_course_taken  current_career_path_id  \
# 0     1 1943-07-03   F     7.0               6.0                     1.0
# 1     2 1991-02-07   M     7.0               5.0                     8.0
# 2     3 1989-12-07   M     7.0               8.0                     8.0
# 3     4 1988-07-31   F     6.0               7.0                     9.0
# 4     5 1963-08-31   M     7.0              14.0                     3.0
#
#    time_spent_hrs job_category  avg_salary  career_path_id  \
# 0            4.99           HR     80000.0             1.0
# 1            4.40           HR     80000.0             8.0
# 2            6.74           HR     80000.0             8.0
# 3           12.31    education     61000.0             9.0
# 4            5.64           HR     80000.0             3.0
#
#             career_path_name  hours_to_complete
# 0             data scientist               20.0
# 1          android developer               27.0
# ...

# %%
df_complete = df_complete.drop(['job_id', 'current_career_path_id', 'career_path_id'], axis=1)
df_complete.head()
# Out:
#    uuid        dob sex  num_course_taken  time_spent_hrs job_category  \
# 0     1 1943-07-03   F               6.0            4.99           HR
# 1     2 1991-02-07   M               5.0            4.40           HR
# 2     3 1989-12-07   M               8.0            6.74           HR
# 3     4 1988-07-31   F               7.0           12.31    education
# 4     5 1963-08-31   M              14.0            5.64           HR
#
#    avg_salary           career_path_name  hours_to_complete
# 0     80000.0             data scientist               20.0
# 1     80000.0          android developer               27.0
# 2     80000.0          android developer               27.0
# 3     61000.0  machine learning engineer               35.0
# 4     80000.0               data analyst               12.0

# %%
df_complete.columns
# Out:
# Index(['uuid', 'dob', 'sex', 'num_course_taken', 'time_spent_hrs',
#        'job_category', 'avg_salary', 'career_path_name', 'hours_to_complete'],
#       dtype='object')
